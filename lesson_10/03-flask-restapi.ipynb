# %% [markdown]
# # Flask REST API
#
# * `flask-restful` [Doc](https://flask-restful.readthedocs.io/en/latest/), [Github](https://github.com/flask-restful/flask-restful) - Status: Active
# * `flask-restplus` [Doc](https://flask-restplus.readthedocs.io/en/stable/), [Github](https://github.com/noirbizarre/flask-restplus) - Status: [Obsolete](https://github.com/noirbizarre/flask-restplus/issues/770)
# * `flask-restx` [Doc](https://flask-restx.readthedocs.io/en/latest/), [Github](https://github.com/python-restx/flask-restx) - Status: Active (fork of `flask-restplus`)

# %%
from flask import Flask
from flask_restx import Api


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(app=app)     # Create new REST-APi and assign to Flask application

if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swaggerui/droid-sans.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swaggerui/swagger-ui.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swaggerui/favicon-16x16.png HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 12:58:19] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 12:59:12] "GET / HTTP/1.1" 200 -
# ...

# %%
from flask import Flask
from flask_restx import Api, Resource


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(app=app)     # Create new REST-APi and assign to Flask application


@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for endpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:02:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:02:06] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:02:06] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:02:06] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:02:12] "GET /first_enpoint HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:02:15] "GET /first_enpoint HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:02:25] "GET /first_enpoint HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:02:33] "GET /first_enpoint HTTP/1.1" 200 -

# %%
from flask import Flask, request
from flask_restx import Api, Resource


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(app=app)     # Create new REST-APi and assign to Flask application


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for enpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }
    
@api.route("/second_enpoint/<int:value_id>")                  # We can get argumets from API
class SecondEndpoint(Resource):
    def put(self, value_id):                                  # Same argument as described on decorator
        payload = request.form                                # use Flask request object and parse webform request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
    def get(self, value_id):
        # Return value from variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        return {value_id: second_endpoints_ids[value_id]}


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:05:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:05:25] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:05:25] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:05:25] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:05:32] "GET /second_enpoint/1 HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:05:40] "GET /second_enpoint/2 HTTP/1.1" 200 -
# [2021-02-03 13:05:43,113] ERROR in app: Exception on /second_enpoint/3 [GET]
# Traceback (most recent call last):
# ...

# %% [markdown]
# ```shell
# curl -X PUT "http://0.0.0.0:5000/second_enpoint/3" -H  "accept: application/json" -d "value=awesome"
# ```

# %%
from flask import Flask, request
from flask_restx import Api, Resource


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(app=app)     # Create new REST-APi and assign to Flask application


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for enpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }
    
@api.route("/second_enpoint/<int:value_id>")                  # We can get argumets from API
class SecondEndpoint(Resource):
    def put(self, value_id):                                  # Same argument as described on decorator
        payload = request.form                                # use Flask request object and parse webform request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Not Found", 404    
        


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:08:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:08:07] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:08:07] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:08:07] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:08:12] "GET /second_enpoint/3 HTTP/1.1" 404 -

# %%
from flask import Flask, request
from flask_restx import Api, Resource


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(app=app)     # Create new REST-APi and assign to Flask application


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for enpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }
    
@api.route("/second_enpoint/<int:value_id>")                  # We can get argumets from API
class SecondEndpoint(Resource):
    def put(self, value_id):                                  # Same argument as described on decorator
        # Now we parse JSON reuest so we need to send by client header "Content-Type: application/json"
        payload = request.json                                # use Flask request object and parse JSON request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Not Found", 404        
        


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:09:21] "PUT /second_enpoint/3 HTTP/1.1" 200 -
# [2021-02-03 13:09:26,696] ERROR in app: Exception on /second_enpoint/3 [PUT]
# Traceback (most recent call last):
#   File "/home/student/.local/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/student/.local/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/student/.local/lib/python3.8/site-packages/flask_restx/api.py", line 375, in wrapper
#     resp = resource(*args, **kwargs)
# ...

# %% [markdown]
# ```shell
# curl -X PUT "http://0.0.0.0:5000/second_enpoint/3" -H  "accept: application/json" --header "Content-Type: application/json" -d '{"value": "awesome"}'
# ```

# %%
help(Api)
# Out:
# Help on class Api in module flask_restx.api:
#
# class Api(builtins.object)
#  |  Api(app=None, version='1.0', title=None, description=None, terms_url=None, license=None, license_url=None, contact=None, contact_url=None, contact_email=None, authorizations=None, security=None, doc='/', default_id=<function default_id at 0x7f87de3e9f70>, default='default', default_label='Default namespace', validate=None, tags=None, prefix='', ordered=False, default_mediatype='application/json', decorators=None, catch_all_404s=False, serve_challenge_on_401=False, format_checker=None, **kwargs)
#  |
#  |  The main entry point for the application.
#  |  You need to initialize it with a Flask Application: ::
#  |
#  |  >>> app = Flask(__name__)
#  |  >>> api = Api(app)
#  |
#  |  Alternatively, you can use :meth:`init_app` to set the Flask application
#  |  after it has been constructed.
#  |
#  |  The endpoint parameter prefix all views and resources:
#  |
# ...

# %%
from flask import Flask, request
from flask_restx import Api, Resource, fields


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample
api = Api(             # Create new REST-Api and assign to Flask application
    app=app,
    title="Awesome REST-API",
    version="0.0.1",
    description="This is Awesome API",
)     
model = api.model(
    "Second Endpoint Data Model", 
    {
        "value": fields.String(required=True, description="Awesome Value"),
    }
)



second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for enpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }
    
@api.route("/second_enpoint/<int:value_id>")                  # We can get argumets from API
class SecondEndpoint(Resource):
    @api.expect(model)                                        # Set expect API model
    def put(self, value_id):                                  # Same argument as described on decorator
        # Now we parse JSON reuest so we need to send by client header "Content-Type: application/json"
        payload = request.json                                # use Flask request object and parse JSON request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
     
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Not Found", 404


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:11:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:11:38] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:11:38] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:11:38] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:12:32] "PUT /second_enpoint/3 HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:12:43] "PUT /second_enpoint/3 HTTP/1.1" 200 -
# [2021-02-03 13:12:57,696] ERROR in app: Exception on /second_enpoint/3 [PUT]
# Traceback (most recent call last):
# ...

# %%
from flask import Flask, request
from flask_restx import Api, Resource, fields
from functools import wraps


app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample

# For authorization use dictionary with a Swagger Authorizations declaration
# https://swagger.io/docs/specification/authentication/
# !!! This dictionary only for swagger. Not for actual autorization !!!
authorizations = {
    "apikey" : {
        "type" : "apiKey",
        "in" : "header",
        "name" : "X-AWESOME-API-KEY"
    }
}


api = Api(             # Create new REST-Api and assign to Flask application
    app=app,
    title="Awesome REST-API",
    version="0.0.1",
    description="This is Awesome API",
    authorizations=authorizations,    # Pass authorizations dictionary
)


model = api.model(
    "Second Endpoint Data Model", 
    {
        "value": fields.String(required=True, description="Awesome Value"),
    }
)


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


def check_autorization(func):
    
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            token = request.headers["X-AWESOME-API-KEY"]
        except KeyError:
            token = None

        if not token:
            return {"message" : "Token is missing."}, 401
        
        # IRL get token value from some other resource: memcache, redis, RDBMS and etc
        # But it's ok for Mock server
        if token != "AWESOME-TOKEN":             
            return {"message" : "Wrong Token."}, 401

        return func(*args, **kwargs)

    return wrapper



@api.route("/first_enpoint")      # For assign endpoint use decorator `Api Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):    # Class Resource for enpoint
    def get(self):                # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }


@api.doc(security="apikey")                                   # Told to swager use apikey from authorizations 
@api.route("/second_enpoint/<int:value_id>")                  # We can get argumets from API
class SecondEndpoint(Resource):
    @api.expect(model)                                        # Set expect API model                        
    @check_autorization                                       # Check Autorization
    def put(self, value_id):                                  # Same argument as described on decorator
        # Now we parse JSON reuest so we need to send by client header "Content-Type: application/json"
        payload = request.json                                # use Flask request object and parse JSON request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
    @check_autorization                                      # Check Autorization
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Not Found", 404        


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:20:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:20:13] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:20:13] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:20:13] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:20:26] "GET /second_enpoint/1 HTTP/1.1" 401 -
# 127.0.0.1 - - [03/Feb/2021 13:20:56] "GET /second_enpoint/1 HTTP/1.1" 200 -

# %%
from flask import Flask, request
from flask_restx import Api, Resource, fields
from functools import wraps

app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample

# For authorization use dictionary with a Swagger Authorizations declaration
# https://swagger.io/docs/specification/authentication/
# !!! This dictionary only for swagger. Not for actual autorization !!!
authorizations = {
    "apikey" : {
        "type" : "apiKey",
        "in" : "header",
        "name" : "X-AWESOME-API-KEY"
    }
}


api = Api(             # Create new REST-Api and assign to Flask application
    app=app,
    title="Awesome REST-API",
    version="0.0.1",
    description="This is Awesome API",
    authorizations=authorizations,    # Pass authorizations dictionary
)

public_ns = api.namespace(
    "public_endpoints", 
    description="This Is Public Endpoints"
)
private_ns = api.namespace(
    "private_endpoints",
    description="This Is Private Endpoints. Authentification Required",
    decorators=[check_autorization]
)


model = api.model(
    "Second Endpoint Data Model", 
    {
        "value": fields.String(required=True, description="Awesome Value"),
    }
)


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


def check_autorization(func):
    
    @wraps(func)
    def wrapper(*args, **kwargs):
        token = None
        try:
            token = request.headers["X-AWESOME-API-KEY"]
        except KeyError:
            token = None

        if not token:
            return {"message" : "Token is missing."}, 401
        
        # IRL get token value from some other resource: memcache, redis, RDBMS and etc
        # But it's ok for Mock server
        if token != "AWESOME-TOKEN":             
            return {"message" : "Wrong Token."}, 401

        return func(*args, **kwargs)

    return wrapper



@public_ns.route("/first_enpoint") # For assign endpoint use decorator `Namespace Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):     # Class Resource for enpoint
    def get(self):                 # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }


@private_ns.doc(security="apikey")
@private_ns.route("/second_enpoint/<int:value_id>")           # We can get arguments from API
class SecondEndpoint(Resource):
    @api.expect(model)                                        # Set expect API model                        
    def put(self, value_id):                                  # Same argument as described on decorator
        # Now we parse JSON reuest so we need to send by client header "Content-Type: application/json"
        payload = request.json                                # use Flask request object and parse JSON request

        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}
    
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Not Found", 404        

@public_ns.route("/third_enpoint")
class ThirdEndpoint(Resource):
    def post(self):
        # return (response, status_code, additional-headers)
        return None, 200, {"X-AWESOME-API-KEY": "AWESOME-TOKEN"}


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:23:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:23:01] "GET /swagger.json HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:23:23] "POST /public_endpoints/third_enpoint HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:23:42] "GET /private_endpoints/second_enpoint/1 HTTP/1.1" 200 -

# %%
from flask import Flask, request
from flask_restx import Api, Resource, fields
from functools import wraps

app = Flask(__name__)  # Setup new Flask application, __name__ use as Sample

# For authorization use dictionary with a Swagger Authorizations declaration
# https://swagger.io/docs/specification/authentication/
# !!! This dictionary only for swagger. Not for actual autorization !!!
authorizations = {
    "apikey" : {
        "type" : "apiKey",
        "in" : "header",
        "name" : "X-AWESOME-API-KEY"
    }
}


api = Api(             # Create new REST-Api and assign to Flask application
    app=app,
    title="Awesome REST-API",
    version="0.0.1",
    description="This is Awesome API",
    authorizations=authorizations,    # Pass authorizations dictionary
)

public_ns = api.namespace(
    "public_endpoints", 
    description="This Is Public Endpoints"
)
private_ns = api.namespace(
    "private_endpoints",
    description="This Is Private Endpoints. Authentification Required",
    decorators=[check_autorization]
)

model = api.model(
    "Second Endpoint Data Model", 
    {
        "value": fields.String(required=True, description="Awesome Value"),
    }
)


second_endpoints_ids = {           # We store data into global variables it's not recommended IRL
    1: "Spam",
    2: "Egg",
}   


def check_autorization(func):
    
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            token = request.headers["X-AWESOME-API-KEY"]
        except KeyError:
            token = None

        if not token:
            return {"message" : "Token is missing."}, 401
        
        # IRL get token value from some other resource: memcache, redis, RDBMS and etc
        # But it's ok for Mock server
        if token != "AWESOME-TOKEN":             
            return {"message" : "Wrong Token."}, 401

        return func(*args, **kwargs)

    return wrapper


@public_ns.doc(responses={200: "OK", 400: "Bad Request", 500: "Internal Server Error"})  # Add documentation for codes
@public_ns.route("/first_enpoint") # For assign endpoint use decorator `Namespace Object`.route: See Flask Pluggable Views
class FirstEndpoint(Resource):     # Class Resource for enpoint
    def get(self):                 # Assign methods for HTTP methods. Like post for POST, get for GET and etc.

        # return object which can convert to JSON
        return {
            "result": 42
        }


@private_ns.doc(security="apikey")
@private_ns.route("/second_enpoint/<int:value_id>")           # We can get arguments from API
class SecondEndpoint(Resource):
    @private_ns.doc(responses={200: "OK", 201: "Created", 400: "Bad Request", 
                               401: "Unauthorized", 500: "Internal Server Error"})  # Add documentation for codes
    @api.expect(model)                                        # Set expect API model                        
    def put(self, value_id):                                  # Same argument as described on decorator
        # Now we parse JSON reuest so we need to send by client header "Content-Type: application/json"
        payload = request.json                                # use Flask request object and parse JSON request

        # If update than return 200, if create return 201
        status = 200 if value_id in second_endpoints_ids else 201
        
        # Get "value" key from request and put into variable
        # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
        second_endpoints_ids[value_id] = payload["value"]      
        return {value_id: second_endpoints_ids[value_id]}, status
    
    @private_ns.doc(responses={200: "OK", 400: "Bad Request", 401: "Unauthorized", 
                               404: "Record Not Found", 500: "Internal Server Error"})
    def get(self, value_id):
        try:
            # Try return value from variable
            # IRL use some more appropriate way like RDBMS, key-value storage, and etc.
            return {value_id: second_endpoints_ids[value_id]}
        except KeyError:
            # return (response, status_code)
            return "Record Not Found", 404        

@public_ns.doc(responses={200: "OK", 400: "Bad Request", 500: "Internal Server Error"}) # Add documentation for codes
@public_ns.route("/third_enpoint")
class ThirdEndpoint(Resource):
    def post(self):
        # return (response, status_code, additional-headers)
        return None, 200, {"X-AWESOME-API-KEY": "AWESOME-TOKEN"}


if __name__ == '__main__':
    app.run(host="0.0.0.0", port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Feb/2021 13:25:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2021 13:25:27] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:25:27] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [03/Feb/2021 13:25:27] "GET /swagger.json HTTP/1.1" 200 -
